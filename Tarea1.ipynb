# %%
# Ejercicio 1.1.2.1 Mensaje definiendo display_message como funcion
# Declaracion de una funcion

# Declaracion de funcion
def display_message():
  print("Declaracion de una funcio en Python")

# Fuera de la funcion
display_message()
# Out:
# Declaracion de una funcio en Python

# %%
# Ejerecicio 1.1.2.2 Libro favorito

# Declaracion de funcion
def libro_favorito(titulo):
  print("Mi libro favorito es "+titulo.title())

# Fuera de la funcion
libro_favorito("El señor de los anillos")
# Out:
# Mi libro favorito es El Señor De Los Anillos

# %%
###    Programa de Playeras ###
def hacerPlayera(talla,texto):
  
  print("La playera es de tamaño"+ talla +" y el texto a cerigrafiar es: "+ textotitle.t)

  
  hacerPlayera("Grande","Hola amigos")

# %%
###    Programa de Playeras grandes ###

def hacerPlayera(talla,texto):
  print("\nLa playera es talla "+ talla+" y el texto a cerigrafiar es: "+ texto)
  

hacerPlayera(talla="Grande", texto="yo")
hacerPlayera(talla="Mediana",texto="yo")
hacerPlayera(talla="Chico",texto="yo")
# Out:
# La playera es talla Grande y el texto a cerigrafiar es: yo
#
# La playera es talla Mediana y el texto a cerigrafiar es: yo
#
# La playera es talla Chico y el texto a cerigrafiar es: yo

# %%
# Programa de descripcion de ciudades

def distintaCiudad(Pais,Ciudad):
    print("\nLa ciudad de "+ Ciudad+"esta en "+Pais)

    distintaCiudad(Pais="México",Ciudad="Ciudad de México")
    distintaCiudad(Pais="México",Ciudad="Chihuahua")
    distintaCiudad(Pais="Brazil",Ciudad="Brazilia")

# %%
# Calculadora

def Sumas(sumador,sumando):
  print("SUMAS")
  sumador=input("Ingrese un numero ")
  print(fsumador)
  sumando=input("Ingrese un numero ")
  print(fsumando)
  r=sumador+sumando
  return r

  print("La suma es:"+ str(Sumas(r)))

  Sumas(0,0)
